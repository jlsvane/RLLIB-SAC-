# %%
from ray import tune
#import ray.rllib.agents.ppo as ppo
import ray.rllib.agents.sac as sac
from ray.tune.logger import pretty_print
from ray.rllib.models import ModelCatalog
from ray.tune.schedulers import AsyncHyperBandScheduler 
import gym

# %%
config = sac.DEFAULT_CONFIG.copy()
config["num_gpus"] = 1
config["log_level"] = "INFO"
config["framework"] = "tf2"
config["eager_tracing"] = True
config["replay_buffer_config"]["capacity"] = int(1e4)
config["optimization"]["actor_learning_rate"] = tune.uniform(1e-4,4e-4)
config["optimization"]["critic_learning_rate"] = tune.uniform(1e-4,4e-4)
config["optimization"]["entropy_learning_rate"] = tune.uniform(1e-4,4e-4)
#config["vf_loss_coeff"] = tune.uniform(0.25,1.0)
config["env"] = "SpaceInvaders-v4"

# %%
asha_scheduler = AsyncHyperBandScheduler(
    time_attr='training_iteration',
    metric='episode_reward_mean',
    mode='max',
    max_t=100,
    grace_period=10,
    reduction_factor=3,
    brackets=1)

# %%
analysis = tune.run(
    "SAC", 
    name="atari_sac_test_1",
    config=config,
    scheduler=asha_scheduler,
    # max_concurrent_trials=4,
    num_samples=5,
    local_dir="atari_test_sac_results",
    #checkpoint_freq=10,
    checkpoint_at_end=True,
    max_failures=5,
    # reuse_actors=True, 
    resume="AUTO",
    stop={"episode_reward_mean": 200}
    )
# Out:
# 2022-08-02 14:06:04,849	INFO trial_runner.py:510 -- No local checkpoint was found. Ray Tune will now start a new experiment.
# (raylet) bash: /home/lupus/miniconda3/envs/atari/lib/libtinfo.so.6: no version information available (required by bash)
# (SACTrainer pid=342227) 2022-08-02 14:06:07,982	INFO trainer.py:2321 -- Executing eagerly (framework='tf2'), with eager_tracing=True. For production workloads, make sure to set eager_tracing=True  in order to match the speed of tf-static-graph (framework='tf'). For debugging purposes, `eager_tracing=False` is the best choice.
# (SACTrainer pid=342227) 2022-08-02 14:06:07,983	WARNING deprecation.py:46 -- DeprecationWarning: `config['prioritized_replay']` has been deprecated. Replay prioritization specified at new location config['replay_buffer_config']['prioritized_replay'] will be overwritten. This will raise an error in the future!
# (SACTrainer pid=342227) 2022-08-02 14:06:07,983	WARNING deprecation.py:46 -- DeprecationWarning: `config[prioritized_replay_alpha]` has been deprecated. config['replay_buffer_config'][prioritized_replay_alpha] should be used for Q-Learning algorithms. Ignore this warning if you are not using a Q-Learning algorithm and still provide prioritized_replay_alpha. This will raise an error in the future!
# (SACTrainer pid=342227) 2022-08-02 14:06:07,983	WARNING deprecation.py:46 -- DeprecationWarning: `config[prioritized_replay_beta]` has been deprecated. config['replay_buffer_config'][prioritized_replay_beta] should be used for Q-Learning algorithms. Ignore this warning if you are not using a Q-Learning algorithm and still provide prioritized_replay_beta. This will raise an error in the future!
# (SACTrainer pid=342227) 2022-08-02 14:06:07,983	WARNING deprecation.py:46 -- DeprecationWarning: `config[prioritized_replay_eps]` has been deprecated. config['replay_buffer_config'][prioritized_replay_eps] should be used for Q-Learning algorithms. Ignore this warning if you are not using a Q-Learning algorithm and still provide prioritized_replay_eps. This will raise an error in the future!
# (SACTrainer pid=342227) 2022-08-02 14:06:07,983	WARNING deprecation.py:46 -- DeprecationWarning: `config[learning_starts]` has been deprecated. config['replay_buffer_config'][learning_starts] should be used for Q-Learning algorithms. Ignore this warning if you are not using a Q-Learning algorithm and still provide learning_starts. This will raise an error in the future!
# (SACTrainer pid=342227) A.L.E: Arcade Learning Environment (version 0.7.5+db37282)
# (SACTrainer pid=342227) [Powered by Stella]
# (SACTrainer pid=342227) 2022-08-02 14:06:08,599	INFO eager_tf_policy.py:337 -- TF-eager Policy (worker=local) running on GPU.
# == Status ==<br>Current time: 2022-08-02 14:06:09 (running for 00:00:05.03)<br>Memory usage on this node: 6.5/31.2 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 90.000: None | Iter 30.000: None | Iter 10.000: None<br>Resources requested: 1.0/12 CPUs, 1.0/1 GPUs, 0.0/17.13 GiB heap, 0.0/8.57 GiB objects (0.0/1.0 accelerator_type:G)<br>Result logdir: /home/lupus/atari_testing/atari_test_sac_results/atari_sac_test_1<br>Number of trials: 5/5 (4 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                      </th><th>status  </th><th>loc              </th><th style="text-align: right;">  optimization/actor_learning_rate</th><th style="text-align: right;">  optimization/critic_learning_rate</th><th style="text-align: right;">  optimization/entropy_learning_rate</th></tr>
# </thead>
# <tbody>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00000</td><td>RUNNING </td><td>10.0.0.118:342227</td><td style="text-align: right;">                       0.000263368</td><td style="text-align: right;">                        0.000204412</td><td style="text-align: right;">                         0.000116892</td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00001</td><td>PENDING </td><td>                 </td><td style="text-align: right;">                       0.000300565</td><td style="text-align: right;">                        0.000347268</td><td style="text-align: right;">                         0.000189542</td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00002</td><td>PENDING </td><td>                 </td><td style="text-align: right;">                       0.000114259</td><td style="text-align: right;">                        0.000163607</td><td style="text-align: right;">                         0.000373034</td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00003</td><td>PENDING </td><td>                 </td><td style="text-align: right;">                       0.000383833</td><td style="text-align: right;">                        0.000246882</td><td style="text-align: right;">                         0.000229115</td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00004</td><td>PENDING </td><td>                 </td><td style="text-align: right;">                       0.000299473</td><td style="text-align: right;">                        0.000355243</td><td style="text-align: right;">                         0.000386971</td></tr>
# </tbody>
# </table><br><br>
# (SACTrainer pid=342227) 2022-08-02 14:06:09,874	INFO rollout_worker.py:1793 -- Built policy map: {}
# (SACTrainer pid=342227) 2022-08-02 14:06:09,874	INFO rollout_worker.py:1794 -- Built preprocessor map: {'default_policy': None}
# (SACTrainer pid=342227) 2022-08-02 14:06:09,874	INFO rollout_worker.py:670 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f13baf31000>}
# (SACTrainer pid=342227) 2022-08-02 14:06:09,881	INFO rollout_worker.py:819 -- Generating sample batch of size 1
# (SACTrainer pid=342227) 2022-08-02 14:06:09,898	INFO sampler.py:664 -- Raw obs from env: { 0: { 'agent0': np.ndarray((84, 84, 4), dtype=float64, min=0.0, max=0.527, mean=0.054)}}
# (SACTrainer pid=342227) 2022-08-02 14:06:09,899	INFO sampler.py:665 -- Info return from env: {0: {'agent0': None}}
# (SACTrainer pid=342227) 2022-08-02 14:06:09,899	INFO sampler.py:905 -- Filtered obs: np.ndarray((84, 84, 4), dtype=float64, min=0.0, max=0.527, mean=0.054)
# (SACTrainer pid=342227) 2022-08-02 14:06:09,899	INFO sampler.py:1135 -- Inputs to compute_actions():
# (SACTrainer pid=342227)
# (SACTrainer pid=342227) { 'default_policy': [ { 'data': { 'agent_id': 'agent0',
# (SACTrainer pid=342227)                                   'env_id': 0,
# (SACTrainer pid=342227)                                   'info': None,
# (SACTrainer pid=342227)                                   'obs': np.ndarray((84, 84, 4), dtype=float64, min=0.0, max=0.527, mean=0.054),
# (SACTrainer pid=342227)                                   'prev_action': None,
# (SACTrainer pid=342227)                                   'prev_reward': None,
# (SACTrainer pid=342227)                                   'rnn_state': None},
# (SACTrainer pid=342227)                         'type': 'PolicyEvalData'}]}
# (SACTrainer pid=342227)
# (SACTrainer pid=342227) 2022-08-02 14:06:10,040	INFO sampler.py:1161 -- Outputs of compute_actions():
# (SACTrainer pid=342227)
# (SACTrainer pid=342227) { 'default_policy': ( np.ndarray((1,), dtype=int32, min=4.0, max=4.0, mean=4.0),
# (SACTrainer pid=342227)                       [],
# (SACTrainer pid=342227)                       { 'action_dist_inputs': np.ndarray((1, 6), dtype=float32, min=-0.015, max=0.023, mean=0.0),
# (SACTrainer pid=342227)                         'action_logp': np.ndarray((1,), dtype=float32, min=-1.792, max=-1.792, mean=-1.792),
# (SACTrainer pid=342227)                         'action_prob': np.ndarray((1,), dtype=float32, min=0.167, max=0.167, mean=0.167)})}
# (SACTrainer pid=342227)
# (SACTrainer pid=342227) 2022-08-02 14:06:10,042	INFO simple_list_collector.py:904 -- Trajectory fragment after postprocess_trajectory():
# (SACTrainer pid=342227)
# (SACTrainer pid=342227) { 'agent0': { 'actions': np.ndarray((1,), dtype=int32, min=4.0, max=4.0, mean=4.0),
# (SACTrainer pid=342227)               'agent_index': np.ndarray((1,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=342227)               'dones': np.ndarray((1,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=342227)               'eps_id': np.ndarray((1,), dtype=int64, min=1148851971.0, max=1148851971.0, mean=1148851971.0),
# (SACTrainer pid=342227)               'infos': np.ndarray((1,), dtype=object, head={'lives': 3, 'episode_frame_number': 94, 'frame_number': 96}),
# (SACTrainer pid=342227)               'new_obs': np.ndarray((1, 84, 84, 4), dtype=float32, min=0.0, max=0.527, mean=0.054),
# (SACTrainer pid=342227)               'obs': np.ndarray((1, 84, 84, 4), dtype=float32, min=0.0, max=0.527, mean=0.054),
# (SACTrainer pid=342227)               'rewards': np.ndarray((1,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=342227)               'unroll_id': np.ndarray((1,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=342227)               'weights': np.ndarray((1,), dtype=float32, min=1.0, max=1.0, mean=1.0)}}
# (SACTrainer pid=342227)
# (SACTrainer pid=342227) 2022-08-02 14:06:10,043	INFO rollout_worker.py:864 -- Completed sample batch:
# (SACTrainer pid=342227)
# (SACTrainer pid=342227) { 'actions': np.ndarray((1,), dtype=int32, min=4.0, max=4.0, mean=4.0),
# (SACTrainer pid=342227)   'agent_index': np.ndarray((1,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=342227)   'dones': np.ndarray((1,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=342227)   'eps_id': np.ndarray((1,), dtype=int64, min=1148851971.0, max=1148851971.0, mean=1148851971.0),
# (SACTrainer pid=342227)   'infos': np.ndarray((1,), dtype=object, head={'lives': 3, 'episode_frame_number': 94, 'frame_number': 96}),
# (SACTrainer pid=342227)   'new_obs': np.ndarray((1, 84, 84, 4), dtype=float32, min=0.0, max=0.527, mean=0.054),
# (SACTrainer pid=342227)   'obs': np.ndarray((1, 84, 84, 4), dtype=float32, min=0.0, max=0.527, mean=0.054),
# (SACTrainer pid=342227)   'rewards': np.ndarray((1,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=342227)   'unroll_id': np.ndarray((1,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=342227)   'weights': np.ndarray((1,), dtype=float32, min=1.0, max=1.0, mean=1.0)}
# (SACTrainer pid=342227)
# (SACTrainer pid=342227) 2022-08-02 14:06:10,043	INFO replay_buffer.py:47 -- Estimated max memory usage for replay buffer is 2.25837 GB (10000.0 batches of size 1, 225837 bytes each), available system memory is 33.507545088 GB
# Result for SAC_SpaceInvaders-v4_7be6c_00000:
#   agent_timesteps_total: 232
#   counters:
#     num_agent_steps_sampled: 232
#     num_agent_steps_trained: 0
#     num_env_steps_sampled: 232
#     num_env_steps_trained: 0
#   custom_metrics: {}
#   date: 2022-08-02_14-06-10
#   done: false
#   episode_len_mean: .nan
#   episode_media: {}
#   episode_reward_max: .nan
#   episode_reward_mean: .nan
#   episode_reward_min: .nan
#   episodes_this_iter: 0
#   episodes_total: 0
#   experiment_id: 345a28c767274bb6973528075812ebd7
#   hostname: lupus-System-Product-Name
#   info:
#     learner: {}
#     num_agent_steps_sampled: 232
#     num_agent_steps_trained: 0
#     num_env_steps_sampled: 232
#     num_env_steps_trained: 0
#   iterations_since_restore: 1
#   node_ip: 10.0.0.118
#   num_agent_steps_sampled: 232
#   num_agent_steps_trained: 0
#   num_env_steps_sampled: 232
#   num_env_steps_sampled_this_iter: 232
#   num_env_steps_trained: 0
#   num_env_steps_trained_this_iter: 0
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 14.5
#     gpu_util_percent0: 0.08499999999999999
#     ram_util_percent: 20.85
#     vram_util_percent0: 0.9325983462791281
#   pid: 342227
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf: {}
#   sampler_results:
#     custom_metrics: {}
#     episode_len_mean: .nan
#     episode_media: {}
#     episode_reward_max: .nan
#     episode_reward_mean: .nan
#     episode_reward_min: .nan
#     episodes_this_iter: 0
#     hist_stats:
#       episode_lengths: []
#       episode_reward: []
#     off_policy_estimator: {}
#     policy_reward_max: {}
#     policy_reward_mean: {}
#     policy_reward_min: {}
#     sampler_perf: {}
#   time_since_restore: 1.0034763813018799
#   time_this_iter_s: 1.0034763813018799
#   time_total_s: 1.0034763813018799
#   timers:
#     training_iteration_time_ms: 3.437
#   timestamp: 1659441970
#   timesteps_since_restore: 0
#   timesteps_total: 232
#   training_iteration: 1
#   trial_id: 7be6c_00000
#   warmup_time: 1.8984942436218262
# == Status ==<br>Current time: 2022-08-02 14:06:10 (running for 00:00:06.05)<br>Memory usage on this node: 6.5/31.2 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 90.000: None | Iter 30.000: None | Iter 10.000: None<br>Resources requested: 1.0/12 CPUs, 1.0/1 GPUs, 0.0/17.13 GiB heap, 0.0/8.57 GiB objects (0.0/1.0 accelerator_type:G)<br>Result logdir: /home/lupus/atari_testing/atari_test_sac_results/atari_sac_test_1<br>Number of trials: 5/5 (4 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                      </th><th>status  </th><th>loc              </th><th style="text-align: right;">  optimization/actor_learning_rate</th><th style="text-align: right;">  optimization/critic_learning_rate</th><th style="text-align: right;">  optimization/entropy_learning_rate</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00000</td><td>RUNNING </td><td>10.0.0.118:342227</td><td style="text-align: right;">                       0.000263368</td><td style="text-align: right;">                        0.000204412</td><td style="text-align: right;">                         0.000116892</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.00348</td><td style="text-align: right;"> 232</td><td style="text-align: right;">     nan</td><td style="text-align: right;">                 nan</td><td style="text-align: right;">                 nan</td><td style="text-align: right;">               nan</td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00001</td><td>PENDING </td><td>                 </td><td style="text-align: right;">                       0.000300565</td><td style="text-align: right;">                        0.000347268</td><td style="text-align: right;">                         0.000189542</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td><td style="text-align: right;">                  </td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00002</td><td>PENDING </td><td>                 </td><td style="text-align: right;">                       0.000114259</td><td style="text-align: right;">                        0.000163607</td><td style="text-align: right;">                         0.000373034</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td><td style="text-align: right;">                  </td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00003</td><td>PENDING </td><td>                 </td><td style="text-align: right;">                       0.000383833</td><td style="text-align: right;">                        0.000246882</td><td style="text-align: right;">                         0.000229115</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td><td style="text-align: right;">                  </td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00004</td><td>PENDING </td><td>                 </td><td style="text-align: right;">                       0.000299473</td><td style="text-align: right;">                        0.000355243</td><td style="text-align: right;">                         0.000386971</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td><td style="text-align: right;">                  </td></tr>
# </tbody>
# </table><br><br>
# (SACTrainer pid=342227) 2022-08-02 14:06:15,592	INFO rollout_worker.py:919 -- Training on concatenated sample batches:
# (SACTrainer pid=342227)
# (SACTrainer pid=342227) { 'count': 256,
# (SACTrainer pid=342227)   'policy_batches': { 'default_policy': { 'actions': np.ndarray((256,), dtype=int32, min=0.0, max=5.0, mean=2.684),
# (SACTrainer pid=342227)                                           'agent_index': np.ndarray((256,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=342227)                                           'dones': np.ndarray((256,), dtype=bool, min=0.0, max=1.0, mean=0.004),
# (SACTrainer pid=342227)                                           'eps_id': np.ndarray((256,), dtype=int64, min=268485664.0, max=1674493760.0, mean=796507451.645),
# (SACTrainer pid=342227)                                           'infos': np.ndarray((256,), dtype=object, head={'lives': 2, 'episode_frame_number': 1206, 'frame_number': 3059}),
# (SACTrainer pid=342227)                                           'new_obs': np.ndarray((256, 84, 84, 4), dtype=float32, min=0.0, max=0.527, mean=0.048),
# (SACTrainer pid=342227)                                           'obs': np.ndarray((256, 84, 84, 4), dtype=float32, min=0.0, max=0.527, mean=0.048),
# (SACTrainer pid=342227)                                           'rewards': np.ndarray((256,), dtype=float32, min=0.0, max=1.0, mean=0.012),
# (SACTrainer pid=342227)                                           'unroll_id': np.ndarray((256,), dtype=int64, min=0.0, max=1476.0, mean=746.816),
# (SACTrainer pid=342227)                                           'weights': np.ndarray((256,), dtype=float32, min=1.0, max=1.0, mean=1.0)}},
# (SACTrainer pid=342227)   'type': 'MultiAgentBatch'}
# (SACTrainer pid=342227)
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv1/kernel:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv1/bias:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv2/kernel:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv2/bias:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv3/kernel:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv3/bias:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv_out/kernel:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv_out/bias:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv1/kernel:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv1/bias:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv2/kernel:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv2/bias:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv3/kernel:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv3/bias:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv_out/kernel:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv_out/bias:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv1/kernel:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv1/bias:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv2/kernel:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv2/bias:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv3/kernel:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv3/bias:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv_out/kernel:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable conv_out/bias:0
# (SACTrainer pid=342227) 2022-08-02 14:06:15,865	INFO eager_tf_policy.py:932 -- Optimizing variable default_policy/log_alpha:0
# Result for SAC_SpaceInvaders-v4_7be6c_00000:
#   agent_timesteps_total: 1500
#   counters:
#     last_target_update_ts: 1500
#     num_agent_steps_sampled: 1500
#     num_agent_steps_trained: 256
#     num_env_steps_sampled: 1500
#     num_env_steps_trained: 256
#     num_target_updates: 1
#   custom_metrics: {}
#   date: 2022-08-02_14-06-16
#   done: false
#   episode_len_mean: 680.0
#   episode_media: {}
#   episode_reward_max: 210.0
#   episode_reward_mean: 197.5
#   episode_reward_min: 185.0
#   episodes_this_iter: 1
#   episodes_total: 2
#   experiment_id: 345a28c767274bb6973528075812ebd7
#   hostname: lupus-System-Product-Name
#   info:
#     last_target_update_ts: 1500
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#
#         - 1.768704891204834
#         - 1.7681167125701904
#         - 1.7698841094970703
#         - 1.762417197227478
#         - 1.769243597984314
#         - 1.7630200386047363
#         - 1.763606309890747
#         - 1.7665870189666748
#         - 1.7619309425354004
#         - 1.7664494514465332
#         - 1.768798589706421
#         - 1.7656829357147217
#         - 1.7732468843460083
#         - 1.7665297985076904
#         - 1.7684897184371948
#         - 1.7691171169281006
#         - 1.760403037071228
#         - 1.767209768295288
#         - 1.765601634979248
#         - 1.762959599494934
#         - 1.7658982276916504
#         - 1.7685439586639404
#         - 1.7697700262069702
#         - 1.7599729299545288
#         - 1.7707620859146118
#         - 1.770817518234253
#         - 1.7671949863433838
#         - 1.7700612545013428
#         - 1.7741420269012451
#         - 1.76865553855896
#         - 1.7627537250518799
#         - 1.7668039798736572
#     num_agent_steps_sampled: 1500
#     num_agent_steps_trained: 256
#     num_env_steps_sampled: 1500
#     num_env_steps_trained: 256
#     num_target_updates: 1
#   iterations_since_restore: 6
#   node_ip: 10.0.0.118
#   num_agent_steps_sampled: 1500
#   num_agent_steps_trained: 256
#   num_env_steps_sampled: 1500
#   num_env_steps_sampled_this_iter: 172
#   num_env_steps_trained: 256
#   num_env_steps_trained_this_iter: 256
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 13.566666666666668
#     gpu_util_percent0: 0.12000000000000001
#     ram_util_percent: 22.433333333333334
#     vram_util_percent0: 0.9350204627077591
#   pid: 342227
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.04133793938047178
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 1.2839812069803833
#     mean_inference_ms: 1.9758395320046196
#     mean_raw_obs_processing_ms: 0.274942503736992
#   sampler_results:
#     custom_metrics: {}
#     episode_len_mean: 680.0
#     episode_media: {}
#     episode_reward_max: 210.0
#     episode_reward_mean: 197.5
#     episode_reward_min: 185.0
#     episodes_this_iter: 1
#     hist_stats:
#       episode_lengths:
#       - 614
#       - 746
#       episode_reward:
#       - 185.0
#       - 210.0
#     off_policy_estimator: {}
#     policy_reward_max: {}
#     policy_reward_mean: {}
#     policy_reward_min: {}
#     sampler_perf:
#       mean_action_processing_ms: 0.04133793938047178
#       mean_env_render_ms: 0.0
#       mean_env_wait_ms: 1.2839812069803833
#       mean_inference_ms: 1.9758395320046196
#       mean_raw_obs_processing_ms: 0.274942503736992
#   time_since_restore: 6.878401041030884
#   time_this_iter_s: 1.8670845031738281
#   time_total_s: 6.878401041030884
#   timers:
#     learn_throughput: 214.743
#     learn_time_ms: 1192.123
#     synch_weights_time_ms: 0.208
#     training_iteration_time_ms: 129.958
#   timestamp: 1659441976
#   timesteps_since_restore: 0
#   timesteps_total: 1500
#   training_iteration: 6
#   trial_id: 7be6c_00000
#   warmup_time: 1.8984942436218262
# == Status ==<br>Current time: 2022-08-02 14:06:16 (running for 00:00:12.03)<br>Memory usage on this node: 7.1/31.2 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 90.000: None | Iter 30.000: None | Iter 10.000: None<br>Resources requested: 1.0/12 CPUs, 1.0/1 GPUs, 0.0/17.13 GiB heap, 0.0/8.57 GiB objects (0.0/1.0 accelerator_type:G)<br>Result logdir: /home/lupus/atari_testing/atari_test_sac_results/atari_sac_test_1<br>Number of trials: 5/5 (4 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name
td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td><td style="text-align: right;">                  </td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00002</td><td>PENDING </td><td>                 </td><td style="text-align: right;">                       0.000114259</td><td style="text-align: right;">                        0.000163607</td><td style="text-align: right;">                         0.000373034</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td><td style="text-align: right;">                  </td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00003</td><td>PENDING </td><td>                 </td><td style="text-align: right;">                       0.000383833</td><td style="text-align: right;">                        0.000246882</td><td style="text-align: right;">                         0.000229115</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td><td style="text-align: right;">                  </td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00004</td><td>PENDING </td><td>                 </td><td style="text-align: right;">                       0.000299473</td><td style="text-align: right;">                        0.000355243</td><td style="text-align: right;">                         0.000386971</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td><td style="text-align: right;">                  </td></tr>
# </tbody>
# </table><br><br>
# Result for SAC_SpaceInvaders-v4_7be6c_00000:
#   agent_timesteps_total: 1600
#   counters:
#     last_target_update_ts: 1600
#     num_agent_steps_sampled: 1600
#     num_agent_steps_trained: 25856
#     num_env_steps_sampled: 1600
#     num_env_steps_trained: 25856
#     num_target_updates: 101
#   custom_metrics: {}
#   date: 2022-08-02_14-06-27
#   done: false
#   episode_len_mean: 680.0
#   episode_media: {}
#   episode_reward_max: 210.0
#   episode_reward_mean: 197.5
#   episode_reward_min: 185.0
#   episodes_this_iter: 0
#   episodes_total: 2
#   experiment_id: 345a28c767274bb6973528075812ebd7
#   hostname: lupus-System-Product-Name
#   info:
#     last_target_update_ts: 1600
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           actor_loss: -3.906062602996826
#           alpha_loss: -0.0004263673909008503
#           alpha_value: 1.0
#           critic_loss: 0.014575705863535404
#           max_q: 2.2371888160705566
#           mean_q: 2.1143319606781006
#           mean_td_error: 0.052595436573028564
#           min_q: 1.9514259099960327
#           target_entropy: 1.755924301147461
#         num_agent_steps_trained: 256
#         td_error:
#         - 0.01644885540008545
#         - 0.06369268894195557
#         - 0.009875178337097168
#         - 0.08134567737579346
#         - 0.07611989974975586
#         - 0.010008573532104492
#         - 0.06176912784576416
#         - 0.013938426971435547
#         - 0.001596689224243164
#         - 0.020633220672607422
#         - 0.026590347290039062
#         - 0.010098457336425781
#         - 0.011800050735473633
#         - 0.028691530227661133
#         - 0.052107810974121094
#         - 0.01621222496032715
#         - 0.08196699619293213
#         - 0.01204538345336914
#         - 0.013834476470947266
#         - 0.010125875473022461
#         - 0.04571080207824707
#         - 0.013262033462524414
#         - 0.03678464889526367
#         - 0.03698420524597168
#         - 0.009731054306030273
#         - 0.02323281764984131
#         - 0.020633220672607422
#         - 0.06252002716064453
#         - 0.00508725643157959
#         - 0.017103195190429688
#         - 0.02655494213104248
#         - 0.02000713348388672
#         - 0.054482221603393555
#         - 0.033266425132751465
#         - 0.0076220035552978516
#         - 0.02000713348388672
#         - 0.02679443359375
#         - 0.009564399719238281
#         - 0.04641127586364746
#         - 0.025359630584716797
#         - 0.022042036056518555
#         - 0.020024538040161133
#         - 2.0519633293151855
#         - 0.01750636100769043
#         - 0.016069889068603516
#         - 0.007018089294433594
#         - 0.08282530307769775
#         - 0.006137490272521973
#         - 0.011226058006286621
#         - 0.016720890998840332
#         - 0.9798192977905273
#         - 0.025333642959594727
# ...
# (SACTrainer pid=346216)               'agent_index': np.ndarray((1,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=346216)               'dones': np.ndarray((1,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=346216)               'eps_id': np.ndarray((1,), dtype=int64, min=1614985656.0, max=1614985656.0, mean=1614985656.0),
# (SACTrainer pid=346216)               'infos': np.ndarray((1,), dtype=object, head={'lives': 3, 'episode_frame_number': 39, 'frame_number': 42}),
# (SACTrainer pid=346216)               'new_obs': np.ndarray((1, 84, 84, 4), dtype=float32, min=0.0, max=0.527, mean=0.055),
# (SACTrainer pid=346216)               'obs': np.ndarray((1, 84, 84, 4), dtype=float32, min=0.0, max=0.527, mean=0.055),
# (SACTrainer pid=346216)               'rewards': np.ndarray((1,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=346216)               'unroll_id': np.ndarray((1,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=346216)               'weights': np.ndarray((1,), dtype=float32, min=1.0, max=1.0, mean=1.0)}}
# (SACTrainer pid=346216)
# (SACTrainer pid=346216) 2022-08-02 14:25:16,046	INFO rollout_worker.py:864 -- Completed sample batch:
# (SACTrainer pid=346216)
# (SACTrainer pid=346216) { 'actions': np.ndarray((1,), dtype=int32, min=4.0, max=4.0, mean=4.0),
# (SACTrainer pid=346216)   'agent_index': np.ndarray((1,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=346216)   'dones': np.ndarray((1,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=346216)   'eps_id': np.ndarray((1,), dtype=int64, min=1614985656.0, max=1614985656.0, mean=1614985656.0),
# (SACTrainer pid=346216)   'infos': np.ndarray((1,), dtype=object, head={'lives': 3, 'episode_frame_number': 39, 'frame_number': 42}),
# (SACTrainer pid=346216)   'new_obs': np.ndarray((1, 84, 84, 4), dtype=float32, min=0.0, max=0.527, mean=0.055),
# (SACTrainer pid=346216)   'obs': np.ndarray((1, 84, 84, 4), dtype=float32, min=0.0, max=0.527, mean=0.055),
# (SACTrainer pid=346216)   'rewards': np.ndarray((1,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=346216)   'unroll_id': np.ndarray((1,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (SACTrainer pid=346216)   'weights': np.ndarray((1,), dtype=float32, min=1.0, max=1.0, mean=1.0)}
# (SACTrainer pid=346216)
# (SACTrainer pid=346216) 2022-08-02 14:25:16,047	INFO replay_buffer.py:47 -- Estimated max memory usage for replay buffer is 2.25837 GB (10000.0 batches of size 1, 225837 bytes each), available system memory is 33.507545088 GB
# Result for SAC_SpaceInvaders-v4_7be6c_00004:
#   agent_timesteps_total: 239
#   counters:
#     num_agent_steps_sampled: 239
#     num_agent_steps_trained: 0
#     num_env_steps_sampled: 239
#     num_env_steps_trained: 0
#   custom_metrics: {}
#   date: 2022-08-02_14-25-16
#   done: false
#   episode_len_mean: .nan
#   episode_media: {}
#   episode_reward_max: .nan
#   episode_reward_mean: .nan
#   episode_reward_min: .nan
#   episodes_this_iter: 0
#   episodes_total: 0
#   experiment_id: 6f23dd11b23f40bc870a97c2671a67cf
#   hostname: lupus-System-Product-Name
#   info:
#     learner: {}
#     num_agent_steps_sampled: 239
#     num_agent_steps_trained: 0
#     num_env_steps_sampled: 239
#     num_env_steps_trained: 0
#   iterations_since_restore: 1
#   node_ip: 10.0.0.118
#   num_agent_steps_sampled: 239
#   num_agent_steps_trained: 0
#   num_env_steps_sampled: 239
#   num_env_steps_sampled_this_iter: 239
#   num_env_steps_trained: 0
#   num_env_steps_trained_this_iter: 0
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 12.7
#     gpu_util_percent0: 0.09
#     ram_util_percent: 23.15
#     vram_util_percent0: 0.9325983462791281
#   pid: 346216
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf: {}
#   sampler_results:
#     custom_metrics: {}
#     episode_len_mean: .nan
#     episode_media: {}
#     episode_reward_max: .nan
#     episode_reward_mean: .nan
#     episode_reward_min: .nan
#     episodes_this_iter: 0
#     hist_stats:
#       episode_lengths: []
#       episode_reward: []
#     off_policy_estimator: {}
#     policy_reward_max: {}
#     policy_reward_mean: {}
#     policy_reward_min: {}
#     sampler_perf: {}
#   time_since_restore: 1.0018284320831299
#   time_this_iter_s: 1.0018284320831299
#   time_total_s: 1.0018284320831299
#   timers:
#     training_iteration_time_ms: 3.64
#   timestamp: 1659443116
#   timesteps_since_restore: 0
#   timesteps_total: 239
#   training_iteration: 1
#   trial_id: 7be6c_00004
#   warmup_time: 1.9125430583953857
#
# Result for SAC_SpaceInvaders-v4_7be6c_00004:
#   agent_timesteps_total: 1347
#   counters:
#     num_agent_steps_sampled: 1347
#     num_agent_steps_trained: 0
#     num_env_steps_sampled: 1347
#     num_env_steps_trained: 0
#   custom_metrics: {}
#   date: 2022-08-02_14-25-21
#   done: true
#   episode_len_mean: 903.0
#   episode_media: {}
#   episode_reward_max: 275.0
#   episode_reward_mean: 275.0
#   episode_reward_min: 275.0
#   episodes_this_iter: 1
#   episodes_total: 1
#   experiment_id: 6f23dd11b23f40bc870a97c2671a67cf
#   hostname: lupus-System-Product-Name
#   info:
#     learner: {}
#     num_agent_steps_sampled: 1347
#     num_agent_steps_trained: 0
#     num_env_steps_sampled: 1347
#     num_env_steps_trained: 0
#   iterations_since_restore: 5
#   node_ip: 10.0.0.118
#   num_agent_steps_sampled: 1347
#   num_agent_steps_trained: 0
#   num_env_steps_sampled: 1347
#   num_env_steps_sampled_this_iter: 277
#   num_env_steps_trained: 0
#   num_env_steps_trained_this_iter: 0
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 15.4
#     gpu_util_percent0: 0.11
#     ram_util_percent: 24.1
#     vram_util_percent0: 0.9325983462791281
#   pid: 346216
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.03965972792854648
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 1.2632252908248223
#     mean_inference_ms: 1.938137173298912
#     mean_raw_obs_processing_ms: 0.26170648523891005
#   sampler_results:
#     custom_metrics: {}
#     episode_len_mean: 903.0
#     episode_media: {}
#     episode_reward_max: 275.0
#     episode_reward_mean: 275.0
#     episode_reward_min: 275.0
#     episodes_this_iter: 1
#     hist_stats:
#       episode_lengths:
#       - 903
#       episode_reward:
#       - 275.0
#     off_policy_estimator: {}
#     policy_reward_max: {}
#     policy_reward_mean: {}
#     policy_reward_min: {}
#     sampler_perf:
#       mean_action_processing_ms: 0.03965972792854648
#       mean_env_render_ms: 0.0
#       mean_env_wait_ms: 1.2632252908248223
#       mean_inference_ms: 1.938137173298912
#       mean_raw_obs_processing_ms: 0.26170648523891005
#   time_since_restore: 5.01095986366272
#   time_this_iter_s: 1.0008783340454102
#   time_total_s: 5.01095986366272
#   timers:
#     training_iteration_time_ms: 3.528
#   timestamp: 1659443121
#   timesteps_since_restore: 0
#   timesteps_total: 1347
#   training_iteration: 5
#   trial_id: 7be6c_00004
#   warmup_time: 1.9125430583953857
# == Status ==<br>Current time: 2022-08-02 14:25:21 (running for 00:19:16.17)<br>Memory usage on this node: 7.6/31.2 GiB<br>Using AsyncHyperBand: num_stopped=3
# Bracket: Iter 90.000: 133.66666666666666 | Iter 30.000: 160.0 | Iter 10.000: 162.5<br>Resources requested: 1.0/12 CPUs, 1.0/1 GPUs, 0.0/17.13 GiB heap, 0.0/8.57 GiB objects (0.0/1.0 accelerator_type:G)<br>Result logdir: /home/lupus/atari_testing/atari_test_sac_results/atari_sac_test_1<br>Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                      </th><th>status    </th><th>loc              </th><th style="text-align: right;">  optimization/actor_learning_rate</th><th style="text-align: right;">  optimization/critic_learning_rate</th><th style="text-align: right;">  optimization/entropy_learning_rate</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00004</td><td>RUNNING   </td><td>10.0.0.118:346216</td><td style="text-align: right;">                       0.000299473</td><td style="text-align: right;">                        0.000355243</td><td style="text-align: right;">                         0.000386971</td><td style="text-align: right;">     5</td><td style="text-align: right;">         5.01096</td><td style="text-align: right;"> 1347</td><td style="text-align: right;"> 275    </td><td style="text-align: right;">                 275</td><td style="text-align: right;">                 275</td><td style="text-align: right;">           903    </td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00001</td><td>TERMINATED</td><td>10.0.0.118:345694</td><td style="text-align: right;">                       0.000300565</td><td style="text-align: right;">                        0.000347268</td><td style="text-align: right;">                         0.000189542</td><td style="text-align: right;">    10</td><td style="text-align: right;">        48.785  </td><td style="text-align: right;"> 1900</td><td style="text-align: right;"> 145    </td><td style="text-align: right;">                 185</td><td style="text-align: right;">                 105</td><td style="text-align: right;">           590.5  </td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00002</td><td>TERMINATED</td><td>10.0.0.118:345884</td><td style="text-align: right;">                       0.000114259</td><td style="text-align: right;">                        0.000163607</td><td style="text-align: right;">                         0.000373034</td><td style="text-align: right;">     5</td><td style="text-align: right;">         5.01404</td><td style="text-align: right;"> 1311</td><td style="text-align: right;"> 210    </td><td style="text-align: right;">                 210</td><td style="text-align: right;">                 210</td><td style="text-align: right;">           783    </td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00003</td><td>TERMINATED</td><td>10.0.0.118:345988</td><td style="text-align: right;">                       0.000383833</td><td style="text-align: right;">                        0.000246882</td><td style="text-align: right;">                         0.000229115</td><td style="text-align: right;">    10</td><td style="text-align: right;">        50.1261 </td><td style="text-align: right;"> 1900</td><td style="text-align: right;">  90    </td><td style="text-align: right;">                 120</td><td style="text-align: right;">                  60</td><td style="text-align: right;">           679.5  </td></tr>
# <tr><td>SAC_SpaceInvaders-v4_7be6c_00004</td><td>TERMINATED</td><td>10.0.0.118:346216</td><td style="text-align: right;">                       0.000299473</td><td style="text-align: right;">                        0.000355243</td><td style="text-align: right;">                         0.000386971</td><td style="text-align: right;">     5</td><td style="text-align: right;">         5.01096</td><td style="text-align: right;"> 1347</td><td style="text-align: right;"> 275    </td><td style="text-align: right;">                 275</td><td style="text-align: right;">                 275</td><td style="text-align: right;">           903    </td></tr>
# </tbody>
# </table><br><br>
# 2022-08-02 14:25:21,306	INFO tune.py:747 -- Total run time: 1156.55 seconds (1156.20 seconds for the tuning loop).

# %%
checkpoints = analysis.get_trial_checkpoints_paths(
    trial=analysis.get_best_trial("episode_reward_mean","max"))

# %%
print(checkpoints[0][0])
# Out:
# /home/lupus/atari_testing/atari_test_sac_results/atari_sac_test_1/SAC_SpaceInvaders-v4_7be6c_00004_4_actor_learning_rate=0.0003,critic_learning_rate=0.0004,entropy_learning_rate=0.0004_2022-08-02_14-25-10/checkpoint_000005/checkpoint-5

# %%
best_config = analysis.get_best_config(metric="episode_reward_mean", mode="max")

# %%
agent = sac.SACTrainer(env="SpaceInvaders-v4", config=best_config)
# Out:
# 2022-08-02 14:25:21,389	INFO trainer.py:2321 -- Executing eagerly (framework='tf2'), with eager_tracing=True. For production workloads, make sure to set eager_tracing=True  in order to match the speed of tf-static-graph (framework='tf'). For debugging purposes, `eager_tracing=False` is the best choice.
# 2022-08-02 14:25:21,390	WARNING deprecation.py:46 -- DeprecationWarning: `config['prioritized_replay']` has been deprecated. Replay prioritization specified at new location config['replay_buffer_config']['prioritized_replay'] will be overwritten. This will raise an error in the future!
# 2022-08-02 14:25:21,391	WARNING deprecation.py:46 -- DeprecationWarning: `config[prioritized_replay_alpha]` has been deprecated. config['replay_buffer_config'][prioritized_replay_alpha] should be used for Q-Learning algorithms. Ignore this warning if you are not using a Q-Learning algorithm and still provide prioritized_replay_alpha. This will raise an error in the future!
# 2022-08-02 14:25:21,391	WARNING deprecation.py:46 -- DeprecationWarning: `config[prioritized_replay_beta]` has been deprecated. config['replay_buffer_config'][prioritized_replay_beta] should be used for Q-Learning algorithms. Ignore this warning if you are not using a Q-Learning algorithm and still provide prioritized_replay_beta. This will raise an error in the future!
# 2022-08-02 14:25:21,391	WARNING deprecation.py:46 -- DeprecationWarning: `config[prioritized_replay_eps]` has been deprecated. config['replay_buffer_config'][prioritized_replay_eps] should be used for Q-Learning algorithms. Ignore this warning if you are not using a Q-Learning algorithm and still provide prioritized_replay_eps. This will raise an error in the future!
# 2022-08-02 14:25:21,392	WARNING deprecation.py:46 -- DeprecationWarning: `config[learning_starts]` has been deprecated. config['replay_buffer_config'][learning_starts] should be used for Q-Learning algorithms. Ignore this warning if you are not using a Q-Learning algorithm and still provide learning_starts. This will raise an error in the future!
# A.L.E: Arcade Learning Environment (version 0.7.5+db37282)
# [Powered by Stella]
# 2022-08-02 14:25:21,998	INFO eager_tf_policy.py:337 -- TF-eager Policy (worker=local) running on GPU.
# 2022-08-02 14:25:23,257	INFO rollout_worker.py:1793 -- Built policy map: {}
# 2022-08-02 14:25:23,257	INFO rollout_worker.py:1794 -- Built preprocessor map: {'default_policy': None}
# 2022-08-02 14:25:23,258	INFO rollout_worker.py:670 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7fdfec15f340>}

# %%
agent.restore(checkpoints[0][0])
# Out:
# 2022-08-02 14:25:23,281	INFO trainable.py:588 -- Restored on 10.0.0.118 from checkpoint: /home/lupus/atari_testing/atari_test_sac_results/atari_sac_test_1/SAC_SpaceInvaders-v4_7be6c_00004_4_actor_learning_rate=0.0003,critic_learning_rate=0.0004,entropy_learning_rate=0.0004_2022-08-02_14-25-10/checkpoint_000005/checkpoint-5
# 2022-08-02 14:25:23,282	INFO trainable.py:597 -- Current state after restoring: {'_iteration': 5, '_timesteps_total': None, '_time_total': 5.01095986366272, '_episodes_total': 1}

# %%
policy = agent.get_policy()

# %%
model = policy.model.action_model.base_model

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  observations (InputLayer)      [(None, 84, 84, 4)]  0           []
#
#  conv1 (Conv2D)                 (None, 21, 21, 16)   4112        ['observations[0][0]']
#
#  conv2 (Conv2D)                 (None, 11, 11, 32)   8224        ['conv1[0][0]']
#
#  conv3 (Conv2D)                 (None, 1, 1, 256)    991488      ['conv2[0][0]']
#
#  lambda (Lambda)                (None, 256)          0           ['conv3[0][0]']
#
#  conv_out (Conv2D)              (None, 1, 1, 6)      1542        ['conv3[0][0]']
#
#  value_out (Dense)              (None, 1)            257         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 1,005,623
# Trainable params: 1,005,623
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow as tf

# %%
tf.keras.utils.plot_model(model, to_file="my_model.png", show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
